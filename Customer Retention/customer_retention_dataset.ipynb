# %%
#import library
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#load data
df = pd.read_csv(r'C:\Users\hp\Desktop\customer_retention_datas\customer_retention_dataset.csv')

# %%
# check first 5 rows
df.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
# check first 5 rows
df.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
# check information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    int64
# ...

# %%
# Describe the dataset
df.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# ...

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
# check null values in the dataframe
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#create variable and add city data into these variable
shoping_city = df['3 Which city do you shop online from?']

# %%
#check city names 
shoping_city.unique()
# Out:
# array(['Delhi', 'Greater Noida', 'Karnal ', 'Bangalore ', 'Noida',
#        'Solan', 'Moradabad', 'Gurgaon ', 'Merrut', 'Ghaziabad',
#        'Bulandshahr'], dtype=object)

# %%
#drop columns
df.drop(columns=['3 Which city do you shop online from?'],inplace=True)

# %%
df['Longer delivery period']
# Out:
# 0         Paytm.com
# 1      Snapdeal.com
# 2         Paytm.com
# 3         Paytm.com
# 4         Paytm.com
#            ...
# 264       Amazon.in
# 265    Flipkart.com
# 266    Snapdeal.com
# 267       Amazon.in
# 268       Amazon.in
# Name: Longer delivery period, Length: 269, dtype: object

# %% [markdown]
# # 'Since How Long You are Shopping Online in these city

# %%
# 'Online shopping in city
plt.figure(figsize=[10,4])
plt.hist(df['5 Since How Long You are Shopping Online ?'])
# plt.labe
# plt.title('Since How Long You are Shopping Online in these city',size=20)
# Out:
# (array([43.,  0., 16.,  0.,  0., 65.,  0., 47.,  0., 98.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
d = list(df['5 Since How Long You are Shopping Online ?'].unique())
d
# Out:
# [5, 4, 3, 1, 2]

# %% [markdown]
# # 6 How many times you have made an online purchase in the past 1 year?

# %%
# '6 How many times you have made an online purchase in the past 1 year?
plt.figure(figsize=[10,4])
plt.barh(shoping_city,df['6 How many times you have made an online purchase in the past 1 year?'])
plt.title('How many times you have made an online purchase in the past 1 year? in city',size=20)
# Out:
# Text(0.5, 1.0, 'How many times you have made an online purchase in the past 1 year? in city')

# %% [markdown]
# # 15 What is your preferred payment Option

# %%
# '6 How many times you have made an online purchase in the past 1 year?
plt.figure(figsize=[10,4])
plt.barh(shoping_city,df['15 What is your preferred payment Option?					                                                                                                                               '])
plt.title('What is your preferred payment Option in city',size=20)
# Out:
# Text(0.5, 1.0, 'What is your preferred payment Option in city')

# %% [markdown]
# # The content on the website must be easy to read and understand in city

# %%
# 'The content on the website must be easy to read and understand
plt.figure(figsize=[10,4])
plt.barh(shoping_city,df['18 The content on the website must be easy to read and understand'])
plt.title('The content on the website must be easy to read and understand in city',size=20)
# Out:
# Text(0.5, 1.0, 'The content on the website must be easy to read and understand in city')

# %% [markdown]
# # Information on similar product to the one highlighted  is important for product comparison in city

# %%
# 'Information on similar product to the one highlighted  is important for product comparison
plt.figure(figsize=[10,4])
plt.barh(shoping_city,df['19 Information on similar product to the one highlighted  is important for product comparison'])
plt.title('Information on similar product to the one highlighted  is important for product comparison in city',size=20)
# Out:
# Text(0.5, 1.0, 'Information on similar product to the one highlighted  is important for product comparison in city')

# %% [markdown]
# # 20 Complete information on listed seller and product being offered is important for purchase decision.

# %%
# 'Information on similar product to the one highlighted  is important for product comparison
plt.figure(figsize=[10,4])
plt.barh(shoping_city,df['20 Complete information on listed seller and product being offered is important for purchase decision.'])
plt.title('Complete information on listed seller and product being offered is important for purchase decision in city',size=20)
# Out:
# Text(0.5, 1.0, 'Complete information on listed seller and product being offered is important for purchase decision in city')

# %% [markdown]
# # 21 All relevant information on listed products must be stated clearly

# %%
# 'Information on similar product to the one highlighted  is important for product comparison
plt.figure(figsize=[10,4])
plt.barh(shoping_city,df['21 All relevant information on listed products must be stated clearly'])
plt.title('All relevant information on listed products must be stated clearly in city',size=20)
# Out:
# Text(0.5, 1.0, 'All relevant information on listed products must be stated clearly in city')

# %%
plt.bar(df['27 Empathy (readiness to assist with queries) towards the customers'],df['27 Empathy (readiness to assist with queries) towards the customers'])
# Out:
# <BarContainer object of 269 artists>

# %%
# 'Ease of navigation in website
plt.figure(figsize=[10,4])
plt.barh(shoping_city,df['22 Ease of navigation in website'])
plt.title('Ease of navigation in website in city',size=20)
# Out:
# Text(0.5, 1.0, 'Ease of navigation in website in city')

# %% [markdown]
# # Money spent on online shopping in the city

# %%
# Money spent on online shopping in the city
plt.figure(figsize=[10,4])
plt.scatter(shoping_city,df['47 Getting value for money spent'])
plt.title('Money spent on online shopping in the city',size=20)
# Out:
# Text(0.5, 1.0, 'Money spent on online shopping in the city')

# %% [markdown]
# # Longer delivery period website in city

# %%
# Longer delivery period website in city
plt.figure(figsize=[14,10])
plt.bar(shoping_city,df['Longer delivery period'])
# Out:
# <BarContainer object of 269 artists>

# %%
# plt.figure(figsize=[6,3])
df.hist(bins=10,figsize=(100,100))
plt.show()

# %%
# Longer delivery period website in city
plt.figure(figsize=[14,10])
plt.bar(shoping_city,df['30 Online shopping gives monetary benefit and discounts'])
# Out:
# <BarContainer object of 269 artists>

# %% [markdown]
# # Easy to use website or application in the city

# %%
# Easy to use website or application
plt.figure(figsize=[14,10])
plt.bar(shoping_city,df['Easy to use website or application'])
# Out:
# <BarContainer object of 269 artists>

# %%
plt.figure(figsize=[14,10])
plt.scatter(shoping_city,df['Easy to use website or application'])

# %% [markdown]
# # Longer time in displaying graphics and photos (promotion, sales period)

# %%
plt.figure(figsize=[14,10])
plt.scatter(shoping_city,df['Longer time in displaying graphics and photos (promotion, sales period)'])

# %%
plt.figure(figsize=[25,25],facecolor='#ADD8E6')
sns.heatmap(new_data.corr(),annot=True,annot_kws={"size": 15})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-e59de7baf7b4> in <module>
#       1 plt.figure(figsize=[25,25],facecolor='#ADD8E6')
# ----> 2 sns.heatmap(new_data.corr(),annot=True,annot_kws={"size": 15})
#
# NameError: name 'new_data' is not defined

# %%
df['41 Monetary savings']
# Out:
# 0      2
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 264    2
# 265    5
# 266    4
# 267    4
# 268    5
# Name: 41 Monetary savings, Length: 269, dtype: int64

# %%
df2=df[['1Gender of respondent', '2 How old are you? ',
       '5 Since How Long You are Shopping Online ?',
       '6 How many times you have made an online purchase in the past 1 year?',
       '7 How do you access the internet while shopping on-line?',
       '8 Which device do you use to access the online shopping?',
       '18 The content on the website must be easy to read and understand',
       '19 Information on similar product to the one highlighted  is important for product comparison',
       '20 Complete information on listed seller and product being offered is important for purchase decision.',
       '21 All relevant information on listed products must be stated clearly',
       '23 Loading and processing speed',
       '24 User friendly Interface of the website',
       '25 Convenient Payment methods',
       '27 Empathy (readiness to assist with queries) towards the customers',
       '28 Being able to guarantee the privacy of the customer',
       '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
       '31 Enjoyment is derived from shopping online',
       '32 Shopping online is convenient and flexible',
       '33 Return and replacement policy of the e-tailer is important for purchase decision',
       '34 Gaining access to loyalty programs is a benefit of shopping online',
       '36 User derive satisfaction while shopping on a good quality website or application',
       '37 Net Benefit derived from shopping online can lead to users satisfaction',
       '38 User satisfaction cannot exist without trust',
       '39 Offering a wide variety of listed product in several category',
       '40 Provision of complete and relevant product information',
       '41 Monetary savings',
       '42 The Convenience of patronizing the online retailer',
       '43 Shopping on the website gives you the sense of adventure',
       '44 Shopping on your preferred e-tailer enhances your social status',
       '45 You feel gratification shopping on your favorite e-tailer',
       '46 Shopping on the website helps you fulfill certain roles',
       '47 Getting value for money spent',]]

# %%
plt.figure(figsize=[35,25],facecolor='#ADD8E6')
sns.heatmap(df2.corr(),annot=True,annot_kws={"size": 15})
# Out:
# <AxesSubplot:>

# %%
# plt.figure(figsize=[6,3])
df2.hist(bins=10,figsize=(30,40))
plt.show()
